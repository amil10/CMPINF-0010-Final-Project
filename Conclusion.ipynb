# %% [markdown]
# # Conclusion

# %% [markdown]
# So after gathering all of our data, which neighborhood is Pittsburgh's "best"?
#
# ![stClaire.jpg](attachment:2da742d0-1b5a-4ccb-a32d-bf002b56a723.jpg)

# %% [markdown]
# # St Claire's!

# %% [markdown]
# ## Rankings

# %% [markdown]
# Crime: 11th
# Traffic: 55th (Yikes)
# Housing: 2nd
